# %%
from dotenv import load_dotenv

load_dotenv("c:/WIP/deep-research-lab/.env")

# %%
import sys
sys.path.append("c:/WIP/deep-research-lab")

from IPython.display import Image, display, Markdown
from multi_agent import supervisor_builder
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver()
agent = supervisor_builder.compile(checkpointer=memory)

# %%
display(Image(agent.get_graph(xray=1).draw_mermaid_png(max_retries=5)))

# %%
from IPython.display import display, Markdown
from rich import print
import uuid 

thread = {"configurable": {
                            "thread_id": str(uuid.uuid4()), #  Checkpoint를 위한 고유 스레드 ID 생성
                           "search_api": "tavily",
                           }}

user = [{"role": "user", "content": "2026년 중소기업벤처부에서 진행하는 R&D 지원사업에 대해서 조사해줘"}]

# async for event in agent.astream({"messages":user}, thread, stream_mode="updates"):
#     node_name, message_chunk = event
    
#     # LLM 응답 실시간 출력
#     print(message_chunk)

response = await agent.ainvoke({"messages": user}, config=thread)

# %%
display(Markdown(agent.get_state(thread).values['final_report']))
# Out:
# # 2026년 중소벤처기업부 R&D 지원사업 개요 보고서
#
# 목적: 본 보고서는 2026년도 중소벤처기업부(중기부)에서 공고한 R&D 지원사업 통합공고와 주요 세부사업(중소기업 기술혁신개발, 창업성장(디딤돌·TIPS), 투·융자연계(스케일업·글로벌 TIPS), 민관공동기술사업화 등)의 핵심 내용·신청요건·절차·실무팁을 한눈에 정리하여, 기업의 사업별 적합성 판단과 접수 준비를 지원하기 위해 작성되었습니다.
#
# 범위: 통합공고의 정책방향(지역·민간투자·사업화·전략투자), 주요 사업별 지원규모·지원비율·지원한도·기간, 공통 신청자격·가점·지원제외 요건, IRIS·SMTECH 등 신청시스템 및 제출서류, 선정평가·사후관리(기술료 포함), 실무 체크리스트 및 권장 일정표, 기업 유형별 적합 매칭과 권장 행동계획을 포함합니다(본문 섹션 참조).
#
# 핵심요약(요지):
# - 정책방향: 비수도권 우대·민간투자 연계 확대·기술사업화 촉진·AI·디지털·탄소 대응 분야 전략투자에 집중합니다.
# - 주요자금: 중기부 기술혁신개발·창업성장·투·융자연계(팁스) 등 대규모 예산이 배정되어 있으며, 대부분 출연금 비율은 75% 내외(예외 65%)입니다.
# - 신청포인트: IRIS를 통한 온라인 접수, 과제별 세부공고·가점·증빙서류 확인 필수, 마감 직전 접수 지연 위험 존재(사전 준비 권장).
#
# 독자 대상: 중소·벤처기업의 경영진·R&D 책임자·기획·재무 담당자, 기술사업화 담당자, 투자 운용사 및 컨설턴트.
#
# 보고서 구조 안내: 본문은 세부 섹션(정책요약, 사업별 개요·비교, 신청요건·절차, 선정평가·사후관리, 실무 체크리스트, 사업별 적합성 등)으로 구성되어 있으며, 각 섹션은 공고·전문기관 자료를 근거로 작성되었습니다.
#
# ## 2026 통합공고 개요 및 정책방향(요약)
#
# 2026년 중소기업 기술개발 통합공고는 지역·민간투자·사업화·분야전략을 핵심으로 한 R&D 재편을 골자로 합니다. 주요 내용:
#
# - 정책방향(4대): ①비수도권 집중 지원(‘26 신규과제 예산 중 주요 5개 사업에 대해 지역기업 50% 목표, 전사업 가점 2점) ②민간투자 연계(스케일업 TIPS 확대·글로벌 TIPS 신설) ③대학·연구소 기술의 사업화 촉진(기술이전·TRL 점프업) ④AI·디지털·탄소 규제 대응 분야 전략투자
#
# - 핵심 예산·프로그램(예): 중소기업 기술혁신개발 4,942억·창업성장기술개발 7,864억·투‧융자연계 4,570억·스케일업 TIPS 1,202억·글로벌 TIPS 647억·탄소감축 과제 50억·Multi AI 36억·표준공정 30억
#
# - 신청: IRIS(www.iris.go.kr) 등 온라인 접수, 세부사업 공고 필수 확인
#
# ### Sources
# 1. https://grant-documents.thevc.kr/285650_(%EC%A4%91%EA%B8%B0%EB%B6%80)_2026%EB%85%84_%EC%A4%91%EC%86%8C%EA%B8%B0%EC%97%85_%EA%B8%B0%EC%88%A0%EA%B0%9C%EB%B0%9C_%EC%A7%80%EC%9B%90%EC%82%AC%EC%97%85_%ED%86%B5%ED%95%A9_%EA%B3%B5%EA%B3%A0.pdf
# 2. https://www.mss.go.kr/common/board/Download.do?bcIdx=1064197&cbIdx=310&streFileNm=52207f6a-24fa-4aeb-8da2-32a9b6bc6933.pdf
# 3. https://files-scs.pstatic.net/2026/01/05/Eqxn5YNsbQ/1.%20(%EC%A4%91%EA%B8%B0%EB%B6%80)_2026%EB%85%84_%EC%A4%91%EC%86%8C%EA%B8%B0%EC%97%85_%EA%B8%B0%EC%88%A0%EA%B0%9C%EB%B0%9C_%EC%A7%80%EC%9B%90%EC%82%AC%EC%97%85_%ED%86%B5%ED%95%A9_%EA%B3%B5%EA%B3%A0.pdf
#
# ## 주요 R&D 사업별 개요(중소기업 기술혁신개발, 창업성장(디딤돌·TIPS), 투·융자연계(팁스), 민관공동기술사업화 등)
#
# - 중소기업기술혁신개발사업: 정부 주도 R&D 지원 사업으로 기술개발·사업화 역량 강화 목적. 공고·제출서식·보안대책 등 절차적 요구사항 존재(공모→평가→과제지원).
#
# - 창업성장(디딤돌): 창업초기·R&D 첫 수행 기업 대상의 입문형 지원. 과제 기간·유형별 차등 지원(통상 최대 1년6개월, 지원한도 예시 2억 원 내외).
#
# - TIPS(투·융자연계): 민간 운영사 선투자·추천 기반의 고성장형 R&D·보육 프로그램. 일반 R&D 패키지(예: R&D 5억+연계 2억 수준), 딥테크 트랙은 더 높은 지원한도(예: R&D 15억 수준)로 후속 VC 연계·멘토링 강조.
#
# - 민관공동기술사업화: 민·관 자금 연계로 기술사업화·대규모 상용화(스케일업) 지원, 공공 R&D 성과의 민간 이전·투자 연계를 촉진.
#
# 관심 사업별로 대상(업력·매출), 선정방식(운영사 추천 vs 정부공모), 지원규모·후속연계가 주요 차이점입니다.
#
# ### Sources
# 1. https://www.mss.go.kr/site/smba/ex/bbs/View.do?cbIdx=310&bcIdx=1064287
# 2. https://enprimavera.tistory.com/397
# 3. https://www.bizinfo.go.kr/cmm/fms/getImageFile.do?atchFileId=FILE_000000000640628&fileSn=0
#
# ## [각 사업별 지원규모·지원비율·지원한도·기간(상세 비교)]
#
# - 중소기업 기술혁신개발: 총 4,942억 원(신규 1,012억). 지원비율 65~75% (수출지향형 65%, 글로벌협력형·국가전략기술 75%). 지원한도: 5억~100억 원(과제별), 기간 2~5년(내역별 다름).
#
# - 민관공동 기술사업화: 총 1,299억. 지원비율 75%, 지원한도 PoC·PoM 1억(1단계)·사업화R&D 최대 10억, 기간 9개월~2년.
#
# - 투·융자연계(팁스·스케일업 등): 총 4,570억. 지원비율 75%, 지원한도 일반형 20억(스케일업), 글로벌팁스 50~60억, 기간 3~4년.
#
# - 창업성장(디딤돌·TIPS): 총 7,864억. 지원비율 75%, 지원한도 디딤돌 2억, TIPS 일반 8억·딥테크 15억, 기간 1.5~3년.
#
# 요약: 대부분 사업 출연금 비율은 75% 수준(예외적 65%), 지원한도·기간은 사업·트랙별로 상이하므로 세부공고 필수 확인.
#
# ### Sources
# 1. https://files-scs.pstatic.net/2026/01/05/Eqxn5YNsbQ/1.%20(%EC%A4%91%EA%B8%B0%EB%B6%80)_2026%EB%85%84_%EC%A4%91%EC%86%8C%EA%B8%B0%EC%97%85_%EA%B8%B0%EC%88%A0%EA%B0%9C%EB%B0%9C_%EC%A7%80%EC%9B%90%EC%82%AC%EC%97%85_%ED%86%B5%ED%95%A9_%EA%B3%B5%EA%B3%A0.pdf
# 2. https://www.kiat.or.kr/front/board/boardContentsView.do?contents_id=71183
# 3. https://www.mss.go.kr/
#
# ## 신청자격·가점·지원제외 사항(공통요건·예외·졸업제·3책5공·보안등급)
#
# - 공통요건: 기관·연구책임자 자격·중복지원 금지·윤리·계약조건 준수 등 공고별 기준 적용. 보안등급은 과제 결과·자료 접근권한에 따라 분류되며 등급별 관리·인력보안 요구가 부과됨(보안관리 지침).
# - 가점: 지역특화·창업·기술이전·산학협력 등 정책목표에 따른 가점 부여(사업 공고 참조).
# - 3책5공(동시수행 제한): 책임연구자 최대 3개, 참여연구자 최대 5개(국가R&D 규정). 과기정통부는 기술사업화 과제·소규모(연평균 연구비 6,000만원 이하)·동일과제 다기관 형태 등을 예외로 인정.
# - 졸업제: 반복지원 제한·성과·기간 기준을 충족하면 ‘졸업’ 처리(사업별 세부기준 따름).
#
# 적용 시 해당 사업 공고·지침을 우선 확인하고, 보안등급·3책5공 예외 신청 근거를 명확히 제출해야 합니다.
#
# ### Sources
# 1. https://www.vitalkorea.kr/uploads/regulation/%EA%B5%AD%EA%B0%80%EC%97%B0%EA%B5%AC%EA%B0%9C%EB%B0%9C%ED%98%81%EC%8B%A0%EB%B2%95%20%EB%A7%A4%EB%89%B4%EC%96%BC.pdf
# 2. https://www.digitaltoday.co.kr/news/articleView.html?idxno=598650
# 3. https://research.kookmin.ac.kr/flexpaper/php/down.php?file=legal_new_20-1&name=legal_new_20-1
#
# ## [신청절차 및 시스템(IRIS·SMTECH) 사용법과 제출서류 안내]
#
# - 사전준비: IRIS(범부처통합연구지원) 가입 → 연구자전환으로 국가연구자번호 발급 → KRI 가입·필수항목(연락처·소속·연구실적 등) 입력(미입력 시 접수불가).
# - SMTECH(중기 R&D) 기본: 개인회원가입·본인인증, 개인정보·기관정보(대표자 계정) 최신화, 기관은 NICE 전자실명인증 필요.
# - 제출서류(일반): 연구계획서, 대표연구실적 및 증빙, 추천서, 주관연구기관확인서. 해당시 자녀출생·가족관계증명서 또는 병적증명서 첨부.
# - 시스템 사용 팁: 파일 형식 PDF/HWP/DOC/DOCX 허용, 대표실적 증빙 권장 100MB 이하, ‘제출(신청완료)’ 클릭 후 접수증 출력 및 주관기관 승인 필요.
# - 주의사항: 마감일 18:00에 접수 차단되므로 마감 3–4시간 전 제출 권장. KRI·기관정보 미비 시 신청 제한.
#
# ### Sources
# 1. https://research.uos.ac.kr/sites/default/files/2024-03/2024%EB%85%84%EB%8F%84%20%EC%9D%B8%EB%AC%B8%EC%82%AC%ED%9A%8C%EB%B6%84%EC%95%BC%20%EB%B0%95%EC%82%AC%EA%B3%BC%EC%A0%95%EC%83%9D%EC%97%B0%EA%B5%AC%EC%9E%A5%EB%A0%A4%EA%B8%88%20%EC%98%A8%EB%9D%BC%EC%9D%B8%20%EC%A0%91%EC%88%98%20%EB%A7%A4%EB%89%B4%EC%96%BC.pdf
# 2. http://www.smtech.go.kr 사용자매뉴얼 (PDF)
# 3. https://www.iris.go.kr/contents/retrieveNoticeView.do?blbdId=00000001&blltSeq=362
#
# ## 선정평가 절차·평가기준 및 기술료·사후관리 규정
#
# - 선정·평가 절차: 공개공모 → 제안서 접수 → 서면검토(적격성) → 전문가·패널 평가(기술성·사업성·파급효과·수행능력) → 우선순위·예산배정; 투명성·사전공지·이해충돌 관리 필수(심사자 독립성·비밀유지).
#
# - 평가지표(예시): 기술성(30–40%), 사업성·시장성(20–30%), 파급효과(10–20%), 수행능력·연구계획·예산타당성(20–30%) — 기관별 가중치 상이.
#
# - 기술료·수익분배: 기술이전 수익에서 권리비용·관리비 공제 후 발명자·운영기관·사업화계획에 따라 분배(많은 대학 사례에서 실시료의 발명자 배분 비율 예: 약 70%).
#
# - 사후관리: 성과검증·중간·종료보고·지적재산권 관리·경상기술료 징수·분납·이행감시·위반시 제재(환수·계약해지) 및 기술사업화 지원 지속.
#
# ### Sources
# 1. https://www.kaia.re.kr/portal/cmm/fms/FileDown.do?atchFileId=FILE_000000000038656&fileSn=1
# 2. https://sh.pknu.ac.kr/kor/CMS/Contents/Contents.do?mCode=MN082
# 3. https://www.msit.go.kr
#
# ## [실무 팁 및 FAQ(가점 증빙, 재무제표, 일정 관리, 평가 준비)]
#
# 간단 실무 체크리스트와 자주 묻는 질문(FAQ).
#
# - 가점 증빙
#   - 공고별 확인기관·증빙서류(인증서, 지정서 등)를 원본 또는 공적 확인서로 제출. 예: 가족친화인증 2.0점 등(조달청 기준).
#   - 발급일·유효기간 표기, 스캔본 + 원본 대조표 준비.
#
# - 재무제표
#   - 최신 연도 감사보고서(또는 세무신고용 재무제표) 제출, 주석·현금흐름 포함 권장.
#   - 평가항목(자기자본비율·유동비율·신용등급)을 미리 계산해 요약표 작성.
#
# - 일정 관리
#   - 마일스톤(문서완성, 내부검토, 제출) 설정, 제출 3영업일 전 최종확인.
#   - 파일명·버전 규칙과 담당자 지정.
#
# - 평가 준비
#   - 입찰공고의 적격심사 항목별(가점·요건) 체크리스트로 모의평가 실행.
#
# FAQ: 서류수정 시 재발급·해명서 제출, 연결/별도 재무제표는 공고 따름.
#
# ### Sources
# 1. https://www.cnse.kr/files/board/b134dade65759c1c7484504492aca958.pdf
# 2. https://www.moef.go.kr/com/cmm/fms/FileDown.do;jsessionid=tx8YkMikCNDfSn9g3Mp8m0w2MS_G-px1J3D5u6J0.node20?atchFileId=ATCH_000000000022789&fileSn=2
# 3. https://sisualtman.com/55
#
# ## 신청 준비 체크리스트와 권장 일정표(기업별 맞춤 준비사항)
#
# 목표: 제출서류 완비·내부승인·증빙확보를 통해 접수·심사 지연 최소화.
#
# - 필수 체크리스트
#   - 법인등기부등본, 사업자등록증, 재무제표(최근 1~3년), 대표자 신분증
#   - 사업계획서/IR 자료, 비용·인력 예산서, 수주·매출 증빙
#   - 지식재산권·인증서·인허가·고용증빙(해당 시)
#   - 내부결재(대표·이사회), 위임장·위탁계약서
# - 준비·제출 팁
#   - 전자신청 포맷(파일명·용량) 사전확인, 증빙원본 스캔 체계화
#   - 외부기관(회계·법률) 검토는 제출 2주 전 완료 권장
#
# 권장 일정(준비기간)
# - 스타트업: 2–4주 (사업계획·IR 집중)
# - 중소기업: 4–8주 (재무·증빙 정리)
# - 중견기업: 6–10주 (내부승인·인력증빙 포함)
# - 대기업: 8–16주 (거버넌스·대규모 증빙)
#
# ### Sources
# 1. https://www.bizinfo.go.kr/cmm/fms/getImageFile.do?atchFileId=FILE_000000000600651&fileSn=0
# 2. https://www.kosmes.or.kr/intro/download/kosmes_guide_manual_v2.pdf
# 3. https://joolaw.co.kr/data/file/law/2083588406_q9YbAH4p_24e0d42dfc22c5ca931e1b565c775443af700c56.pdf
#
# ## 사업별로 적합한 기업 유형 및 전략적 매칭
#
# - 플랫폼
#   - 유리한 기업: 네트워크 효과·데이터 역량 보유, 낮은 변동비로 확장 가능한 스타트업·대기업
#   - 전략: 초기 사용자 확보(인센티브), 데이터·API 우선 투자, 파트너 에코시스템 구축
#
# - 제조(제품)
#   - 유리한 기업: 자본·설비·공정노하우 보유, 공급망·품질관리 역량 있는 중견·대기업
#   - 전략: 규모의 경제·수직통합·품질 차별화, 자동화·R&D 투자 우선
#
# - 서비스(전문·현장)
#   - 유리한 기업: 인력·현장 네트워크·브랜딩 강한 기업(프랜차이즈·전문업체)
#   - 전략: 표준화·프로세스·고객경험 관리, 지역화·신속대응 역량 강화
#
# - 구독 모델
#   - 유리한 기업: 반복적 사용·높은 고객 유지 가능 서비스·SW·콘텐츠 제공자
#   - 전략: 고객 유지(LTV 최적화), 가격·플랜 실험, 연속적 제품 개선
#
# - B2B vs B2C 매칭 포인트
#   - B2B: 긴 영업주기·관계관리·규모 있는 세일즈·커스터마이제이션 역량 필요
#   - B2C: 브랜드·마케팅·물류·스케일된 고객지원 역량 우선
#
# ### Sources
# 1. https://www.mckinsey.com
# 2. https://hbr.org
# 3. https://www.bcg.com
#
# ## [참고자료·공식공고·전문기관 연락처 및 유용한 링크 모음]
#
# 간단 안내: 주요 공식 포털과 부처 공고·연락처 페이지를 모아 신속하게 접근할 수 있도록 정리했습니다.
#
# - 정부24(https://plus.gov.kr) — 중앙 민원·혜택·공고 통합 포털. 고객센터·민원조회 제공.
# - 중소벤처기업부 사업공고(https://www.mss.go.kr) — 중소기업 지원사업·공모·콜센터 안내.
# - 농림축산식품부 공지(https://www.mafra.go.kr) — 농업·축산 분야 공지·상담창구 제공.
# - 고용노동부(https://www.moel.go.kr) — 고용·노동 관련 공고·정책·상담 서비스.
#
# 이용 팁: 공식 정부사이트는 go.kr/or.kr 도메인 사용 및 HTTPS 자물쇠 표시 확인. 공고 확인 시 공고번호·게시일·문의처를 반드시 확인하세요.
#
# ### Sources
# 1. https://plus.gov.kr
# 2. https://www.mss.go.kr
# 3. https://www.mafra.go.kr
# 4. https://www.moel.go.kr
#
# ## 요약 및 다음 단계(권장 행동계획)
#
# 간단 요약
# - 핵심 결론: 주요 이슈를 식별했고(문제·원인), 실행 가능한 해법과 우선순위를 도출함.
# - 문서 목적: 의사결정자에게 즉시 실행 가능한 30/90/180일 계획과 성과지표(KPI) 제시.
#
# 권장 행동계획(우선순위)
# - 1) 우선순위 확정: 영향·시급성 기준으로 상위 3개 과제 선정(책임자 지정, 2주 내).
# - 2) 자원·예산 배정: 필요 인력·예산 확정(30일) — 예산 근거는 유사 기관 사례 참고(주 예산 보고서).
# - 3) KPI 설정: 명확·수량화 가능·이해관계자 합의 필요(CIO 권고). 핵심 지표 3개 설정(성과·품질·일정).
# - 4) 실행·모니터링: 30/90/180일 마일스톤과 주간 보고 체계 구축.
#
# 리스크 및 완화
# - 주요 리스크: 자원 부족·이해관계자 불일치 → 조기 합의·우선순위 재조정으로 완화.
#
# ### Sources
# 1. https://ofm.wa.gov/ko/budget/state-budget-2023-25/proposed-biennial/agency-recommendation-summaries/461/
# 2. https://www.cio.com/article/3532081/%EA%B8%B0%EA%B3%A0-%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%ED%8C%80-%EC%84%B1%EA%B3%BC-%EC%B8%A1%EC%A0%95%EC%9D%84-%EC%9C%84%ED%95%9C-kpi-%EC%84%A4%EC%A0%95%C2%B7%ED%99%9C%EC%9A%A9-%EA%B0%80%EC%9D%B4.html
# 3. https://aithor.com/blog/ko-kr/how-to-write-an-executive-summary
#
# ## 결론
#
# 요약: 2026년 중소벤처기업부의 R&D 지원체계는 ‘지역(비수도권) 집중·민간투자 연계 확대·기술사업화 촉진·전략분야(디지털·AI·탄소 대응 등) 우선투자’라는 정책방향을 바탕으로, 중소기업의 전주기 성장(창업→스케일업→글로벌)을 지원하도록 설계되어 있습니다. 주요 사업(중소기업 기술혁신개발, 창업성장(디딤돌·TIPS), 투·융자연계(스케일업·글로벌팁스), 민관공동기술사업화 등)은 과제유형별로 지원한도·기간·정부출연비율(대부분 75% 내외)이 정해져 있으며, IRIS를 통한 온라인 접수·엄격한 자격심사 및 보안등급 분류·기술료 징수 기준 등 사후관리 체계가 적용됩니다.
#
# 핵심 시사점:
# - 사업 선택 전략: 기업의 업력·매출·기술성숙도(TRL)·민간투자 유무에 따라 적합한 사업이 달라집니다. (예: 창업초기·매출저(≤20억) 기업은 디딤돌, 투자유치·스케일업 준비 기업은 팁스 계열)
# - 준비 우선순위: IRIS 계정·국가연구자번호, 최근 재무제표(부채비율 등), 가점 증빙서류, 연구개발계획서(요약·본문1~2) 초안 등을 사전에 준비해야 접수 마감일 전에 안정적으로 제출할 수 있습니다.
# - 리스크 관리: 마감일 전 날 전산혼잡이 빈번하므로 최소 마감 2~3일 전 제출 권장. 부정확한 제출·허위기재는 지원제외 및 환수 등 강한 제재 대상입니다.
# - 지역·가점 활용: 2026년에는 비수도권 가점(2점 등)과 여성·고용 관련 가점 등 확대되므로 해당 조건을 충족하면 경쟁력이 상승합니다.
#
# 권장 행동계획(단계별):
# 1) 적합 사업선별(1주): 기업 현황(업력·매출·기술성숙도·투자상태)을 기준으로 2~3개 후보사업 선정. 필요하면 제가 기업정보를 바탕으로 추천드립니다.
# 2) 문서·증빙 준비(2~3주): 연구개발계획서 초안, 재무제표(최근 연도), 가점증빙(수상·고용증빙·여성기업 확인서 등), 보안등급 검토.
# 3) IRIS·국가연구자번호·공인인증 준비(즉시): 담당연구자 및 참여연구원 모두 국가연구자번호 필요. 접수 전 필수.
# 4) 내부검토·사전검토(1주): 외부 검토(컨설턴트 또는 전문기관)를 통해 연구계획서 보완.
# 5) 제출 및 후속관리: 마감 2~3일 전 제출 완료, 선정 시 협약·사후관리(기술료 등) 대응계획 수립.
#
# 연락 및 도움말: 공고·시스템·전문기관 문의는 1357(중소기업 통합콜센터), IRIS 콜센터 1877-2041, 각 사업의 전문기관(중소기업기술정보진흥원 등)을 통해 확인 가능. 필요하시면 귀사에 맞춘 사업 적합성 분석, R&D계획서 초안 작성, 가점 증빙 리스트 정리 등을 도와드리겠습니다.
#
# 마지막으로: 세부사업별 공고문(사업별 시행계획과 붙임문서)을 반드시 확인하여 신청자격·제출서류·일정·평가기준의 최신 변경사항을 반영하시기 바랍니다.

# %%
import requests 

response = requests.get(
  "https://api.tavily.com/usage",
  headers={"Authorization": "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"}
)

response.json()
